# %%
pip install -r requirements.txt
# Out:
# ...
#   Using cached lida-0.0.14-py3-none-any.whl (7.3 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 10.9 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached scipy-1.14.1-cp310-cp310-macosx_14_0_arm64.whl (23.1 MB)
# ...
#   Using cached matplotlib-3.9.2-cp310-cp310-macosx_11_0_arm64.whl (7.8 MB)
# ...
#   Using cached geopandas-1.0.1-py3-none-any.whl (323 kB)
# ...
#   Using cached statsmodels-0.14.4-cp310-cp310-macosx_11_0_arm64.whl (9.9 MB)
# ...
#   Using cached python_multipart-0.0.12-py3-none-any.whl (23 kB)
# ...
#   Using cached altair-5.4.1-py3-none-any.whl (658 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 KB 5.6 MB/s eta 0:00:00a 0:00:01
# ...
#   Using cached kaleido-0.2.1-py2.py3-none-macosx_11_0_arm64.whl (85.8 MB)
# ...
#   Using cached matplotlib_venn-1.1.1-py3-none-any.whl
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.7/94.7 KB 4.6 MB/s eta 0:00:00
# ...
#   Using cached plotnine-0.13.6-py3-none-any.whl (1.3 MB)
# ...

# %%
import os

os.environ['OPENAI_API_KEY'] = 'sk-jtWMopTjPSzMcw8xqBH_foR55AR_GpcETnewbUIe8gT3BlbkFJewh93C_3wh11gJflvKyVJ7SPxwLYqAwB82yCwtp-QA'
